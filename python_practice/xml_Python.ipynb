# %% [markdown]
# # Here we use lxml to edit .xml files from python

# %%
try:
  from lxml import etree
  print("running with lxml.etree")
except ImportError:
  try:
    # Python 2.5
    import xml.etree.cElementTree as etree
    print("running with cElementTree on Python 2.5+")
  except ImportError:
    try:
      # Python 2.5
      import xml.etree.ElementTree as etree
      print("running with ElementTree on Python 2.5+")
    except ImportError:
      try:
        # normal cElementTree install
        import cElementTree as etree
        print("running with cElementTree")
      except ImportError:
        try:
          # normal ElementTree install
          import elementtree.ElementTree as etree
          print("running with ElementTree")
        except ImportError:
          print("Failed to import ElementTree from any known place")
# Out:
# running with lxml.etree

# %%
sources = etree.Element("sources")
source = etree.SubElement(sources,"source").text = "Source1"
print sources.tag
# Out:
# sources

# %%
print etree.tostring(sources,pretty_print=True)
# Out:
# <sources>
#   <source>Source1</source>
# </sources>

# %%
source_library = etree.parse("/Users/Francis/fermiTools/practiceFermiTools/3C279_input_model.xml")

# %%
xmlData = etree.tostring(source_library,pretty_print=True)
print xmlData
# Out:
# <source_library title="source library">
#
# <!-- Point Sources -->
#
# <!-- Sources between [0.0,8.0) degrees of ROI center -->
# <source ROI_Center_Distance="7.297" name="3FGL J1228.4-0317" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.29703262265 degrees away from ROI center -->
# 	<!-- Source signficance 5.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="2.12171277184"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.27196"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1458.882446"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="187.111"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.2954"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="6.864" name="3FGL J1233.7-0145" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 6.86421978889 degrees away from ROI center -->
# 	<!-- Source signficance 15.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="8.25105066736"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.22139"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1254.953003"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="188.434"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-1.7566"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="5.395" name="3FGL J1234.7-0437" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 5.39536678701 degrees away from ROI center -->
# 	<!-- Source signficance 4.9 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="3.90215966229"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.64911"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="8848.023438"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="188.697"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-4.6215"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.414" name="3FGL J1239.1-1158" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.41376789605 degrees away from ROI center -->
# 	<!-- Source signficance 6.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-11" value="2.22605267552"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="3.06671"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="270.158112"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="189.799"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.9776"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="4.634" name="3FGL J1243.9-0217" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 4.63377373269 degrees away from ROI center -->
# 	<!-- Source signficance 5.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.03579444284"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.18595"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1849.088135"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="190.977"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-2.2843"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="1.591" name="3FGL J1249.5-0546" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 1.59083496103 degrees away from ROI center -->
# 	<!-- Source signficance 5.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="2.2978496818"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.41291"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1453.287231"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="192.382"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.7794"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="3.548" name="3FGL J1250.2-0233" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 3.54770617793 degrees away from ROI center -->
# 	<!-- Source signficance 5.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-16" value="5.34960439679"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.09753"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="33148.875000"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="192.568"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-2.5638"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="3.954" name="3FGL J1251.0-0203" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 3.95445360053 degrees away from ROI center -->
# 	<!-- Source significane 6.9 is less than specified minimum for a free source of 120.0 but variability index 93.48 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="6.937092502"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.38573"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="958.773438"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="192.763"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-2.0566"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="0.067" name="3FGL J1256.1-0547" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 0.0673511866021 degrees away from ROI center -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-10" value="3.71426917001"/>
# 		<parameter free="1" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.23294"/>
# 		<parameter free="1" max="10.0" min="0.0" name="beta" scale="1.0" value="0.0789386"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="341.966"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="194.041"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.7912"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="5.962" name="3FGL J1256.3-1146" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 5.9617350176 degrees away from ROI center -->
# 	<!-- Source signficance 11.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="6.96275380559"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.90701"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3130.760010"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="194.087"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.7808"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="3.105" name="3FGL J1304.8-0338" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 3.10484964041 degrees away from ROI center -->
# 	<!-- Source significane 4.4 is less than specified minimum for a free source of 120.0 but variability index 73.54 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.57627993232"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.28052"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1462.262329"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="196.206"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.6478"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.111" name="3FGL J1310.2-1159" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.1105501606 degrees away from ROI center -->
# 	<!-- Source signficance 6.9 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="1.23810526379"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.79755"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="5606.663086"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="197.568"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.9852"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.465" name="3FGL J1311.0+0036" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.46462394463 degrees away from ROI center -->
# 	<!-- Source signficance 4.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="1.93439031747"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.54519"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="12643.100586"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="197.771"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="0.6138"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.896" name="3FGL J1312.7+0051" type="PointSource">
# 	<spectrum apply_edisp="false" type="PLSuperExpCutoff">
# 	<!-- Source is 7.8963708807 degrees away from ROI center -->
# 	<!-- Source significance 20.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="5.75055584748"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index1" scale="-1.0" value="1.52349"/>
# 		<parameter free="0" max="1e5" min="1e1" name="Cutoff" scale="1.0" value="2803.493408"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="837.744446"/>
# 		<parameter free="0" max="5" min="0" name="Index2" scale="1.0" value="1.000000"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="198.195"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="0.861"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="4.455" name="3FGL J1312.8-0424" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 4.45525925425 degrees away from ROI center -->
# 	<!-- Source significane 16.5 is less than specified minimum for a free source of 120.0 but variability index 388.24 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="4.81112155323"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.48721"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="616.724854"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="198.221"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-4.4027"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="5.227" name="3FGL J1315.7-0732" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 5.22727680817 degrees away from ROI center -->
# 	<!-- Source significane 12.9 is less than specified minimum for a free source of 120.0 but variability index 72.48 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.92119730498"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.01919"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2099.555420"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="198.947"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-7.5485"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.683" name="3FGL J1322.8-0938" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.68319932106 degrees away from ROI center -->
# 	<!-- Source significane 14.4 is less than specified minimum for a free source of 120.0 but variability index 178.64 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="8.2515383415"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.6294"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="480.361298"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="200.706"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-9.6449"/>
# 	</spatialModel>
# </source>
#
# <!-- Sources between [8.0,16.0) degrees of ROI center -->
# <source ROI_Center_Distance="15.917" name="3FGL J1155.3-1112" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.9170911067 degrees away from ROI center -->
# 	<!-- Source signficance 5.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="4.40638482326"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.53449"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="7846.404785"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="178.827"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.2029"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.068" name="3FGL J1159.6-0723" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.0676843761 degrees away from ROI center -->
# 	<!-- Source signficance 8.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.21623007889"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.1039"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2149.063477"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="179.906"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-7.3924"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.926" name="3FGL J1200.4+0202" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.9264684902 degrees away from ROI center -->
# 	<!-- Source signficance 8.8 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.21578325207"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.03552"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2072.597900"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="180.111"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="2.0418"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.871" name="3FGL J1204.3-0708" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.8705990938 degrees away from ROI center -->
# 	<!-- Source signficance 15.8 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.26072682025"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.8612"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2905.877197"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="181.094"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-7.1411"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.768" name="3FGL J1216.6-0557" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 9.76826564273 degrees away from ROI center -->
# 	<!-- Source signficance 4.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="7.0740846991"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.483"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="847.284363"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="184.161"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.9646"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.845" name="3FGL J1218.0-0029" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 10.8453070836 degrees away from ROI center -->
# 	<!-- Source significane 8.7 is less than specified minimum for a free source of 120.0 but variability index 83.88 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="7.23918266912"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.38836"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1099.319824"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="184.513"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-0.4972"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.361" name="3FGL J1218.4-0121" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 10.3612160665 degrees away from ROI center -->
# 	<!-- Source signficance 13.8 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="5.04116767861"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.19519"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1561.669312"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="184.606"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-1.3627"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.382" name="3FGL J1219.7-0314" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 9.38160159135 degrees away from ROI center -->
# 	<!-- Source signficance 8.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.03773807852"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.00122"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2359.194092"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="184.932"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.2353"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="8.583" name="3FGL J1221.5-0632" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 8.58297679387 degrees away from ROI center -->
# 	<!-- Source signficance 11.5 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="6.0494128153"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.24979"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1255.948364"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="185.378"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-6.55"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="13.074" name="3FGL J1222.4+0414" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 13.0741398375 degrees away from ROI center -->
# 	<!-- Source significance 30.0 is less than specified minimum for a free source of 120.0 but variability index 188.40 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-10" value="1.11763286126"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.50852"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.214161"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="263.937"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="185.611"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="4.234"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.431" name="3FGL J1226.8+0638" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.4310937065 degrees away from ROI center -->
# 	<!-- Source signficance 5.5 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="3.46949502107"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.56446"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="8902.508789"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="186.7"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="6.649"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.478" name="3FGL J1226.9-1329" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 10.4784830665 degrees away from ROI center -->
# 	<!-- Source signficance 13.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.68987328471"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.98275"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2482.793701"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="186.742"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-13.4988"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.318" name="3FGL J1229.1+0202" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 10.3182857241 degrees away from ROI center -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-10" value="7.64849072965"/>
# 		<parameter free="1" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.51628"/>
# 		<parameter free="1" max="10.0" min="0.0" name="beta" scale="1.0" value="0.107886"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="245.941"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="187.287"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="2.041"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.351" name="3FGL J1231.2-1411" type="PointSource">
# 	<spectrum apply_edisp="false" type="PLSuperExpCutoff">
# 	<!-- Source is 10.3508469452 degrees away from ROI center -->
# 	<!-- Source significance 105.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-11" value="3.08963236939"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index1" scale="-1.0" value="1.1804"/>
# 		<parameter free="0" max="1e5" min="1e1" name="Cutoff" scale="1.0" value="2574.697754"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="917.884216"/>
# 		<parameter free="0" max="5" min="0" name="Index2" scale="1.0" value="1.000000"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="187.801"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-14.1981"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.799" name="3FGL J1238.2-1958" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.7988431438 degrees away from ROI center -->
# 	<!-- Source signficance 8.5 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="6.58906685724"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.34868"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1030.790894"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="189.565"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-19.9831"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="13.900" name="3FGL J1239.4+0727" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 13.9000544694 degrees away from ROI center -->
# 	<!-- Source signficance 8.0 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="6.82570644971"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.39759"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1011.890381"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="189.873"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="7.4625"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.301" name="3FGL J1239.5+0443" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 11.3010308437 degrees away from ROI center -->
# 	<!-- Source significance 65.0 is less than specified minimum for a free source of 120.0 but variability index 1257.65 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-11" value="6.12414355339"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.20432"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.112085"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="424.897"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="189.895"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="4.7192"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.777" name="3FGL J1241.6-1456" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 9.7774006442 degrees away from ROI center -->
# 	<!-- Source signficance 6.2 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="3.87271425594"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.95942"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3020.241455"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="190.406"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-14.9452"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.962" name="3FGL J1241.9+0639" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.962172155 degrees away from ROI center -->
# 	<!-- Source signficance 5.2 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="9.04040382187"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.78168"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="5711.555176"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="190.475"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="6.6613"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="8.229" name="3FGL J1250.5+0217" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 8.22873148558 degrees away from ROI center -->
# 	<!-- Source signficance 6.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="3.1433341173"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.32794"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1259.425415"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="192.626"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="2.2969"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.300" name="3FGL J1253.7+0327" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 9.30015252631 degrees away from ROI center -->
# 	<!-- Source signficance 12.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="6.69547222027"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.84179"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3417.689453"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="193.435"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="3.4642"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.201" name="3FGL J1258.6-1800" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.2014547221 degrees away from ROI center -->
# 	<!-- Source significane 22.4 is less than specified minimum for a free source of 120.0 but variability index 247.30 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="9.17906636116"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.44648"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="557.331421"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="194.65"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-18.0039"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.431" name="3FGL J1301.6+0832" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.4312246135 degrees away from ROI center -->
# 	<!-- Source signficance 13.6 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="2.14075393697"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.37894"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="765.506470"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="195.418"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="8.5398"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.494" name="3FGL J1304.9-2109" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.4938483749 degrees away from ROI center -->
# 	<!-- Source signficance 4.9 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="5.8130482036"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.14788"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2515.447998"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="196.246"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-21.1575"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.153" name="3FGL J1309.0+0347" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 10.1531010759 degrees away from ROI center -->
# 	<!-- Source signficance 4.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="6.743807986"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.08547"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1972.809570"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="197.258"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="3.7909"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="8.772" name="3FGL J1318.7-1232" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 8.77218567895 degrees away from ROI center -->
# 	<!-- Source signficance 8.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="7.51060617778"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.34752"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="992.460327"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="199.694"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-12.5408"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.904" name="3FGL J1322.3+0839" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.9036567867 degrees away from ROI center -->
# 	<!-- Source significane 7.8 is less than specified minimum for a free source of 120.0 but variability index 73.85 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="3.70699104009"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.25257"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1232.444214"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="200.582"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="8.6574"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.375" name="3FGL J1322.6-1619" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.3751905452 degrees away from ROI center -->
# 	<!-- Source signficance 5.3 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="3.88026091293"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.35643"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1108.856079"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="200.666"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-16.3189"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.409" name="3FGL J1322.9+0435" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.4089883853 degrees away from ROI center -->
# 	<!-- Source signficance 6.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="1.13660030823"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.73958"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="5297.357422"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="200.733"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="4.5966"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="8.280" name="3FGL J1329.1-0536" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 8.28049245461 degrees away from ROI center -->
# 	<!-- Source signficance 5.6 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.8921494959"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.35159"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1727.645752"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="202.299"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.6081"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.574" name="3FGL J1331.1-1328" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 11.5742648687 degrees away from ROI center -->
# 	<!-- Source significane 5.5 is less than specified minimum for a free source of 120.0 but variability index 81.58 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="2.54386762306"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.3738"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1526.140991"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="202.787"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-13.4818"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.018" name="3FGL J1332.0-0508" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 9.01841422236 degrees away from ROI center -->
# 	<!-- Source significance 49.7 is less than specified minimum for a free source of 120.0 but variability index 1874.97 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-11" value="4.10766663739"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.45441"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.17614"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="543.838"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="203.015"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.1476"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.513" name="3FGL J1332.6-1256" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 11.5130398587 degrees away from ROI center -->
# 	<!-- Source significane 19.3 is less than specified minimum for a free source of 120.0 but variability index 296.67 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="2.37151227475"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.41706"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1056.578247"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="203.158"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-12.9387"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.521" name="3FGL J1337.6-1257" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 12.5208433017 degrees away from ROI center -->
# 	<!-- Source significance 19.1 is less than specified minimum for a free source of 120.0 but variability index 100.09 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-12" value="6.05034642179"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.36626"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.205617"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="715.704"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="204.415"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-12.9571"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.766" name="3FGL J1339.8-0133" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 11.7660737304 degrees away from ROI center -->
# 	<!-- Source signficance 5.0 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="1.0200105734"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.46877"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="723.633972"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="204.971"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-1.5556"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.270" name="3FGL J1340.6-0408" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 11.2696173964 degrees away from ROI center -->
# 	<!-- Source signficance 6.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="7.200698913"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.98138"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2449.177246"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="205.166"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-4.1371"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.454" name="3FGL J1349.6-1133" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.454329785 degrees away from ROI center -->
# 	<!-- Source significane 18.4 is less than specified minimum for a free source of 120.0 but variability index 642.10 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="3.49776652954"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.39194"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="770.664734"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="207.407"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.5596"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.177" name="3FGL J1351.1+0030" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.1773061922 degrees away from ROI center -->
# 	<!-- Source significane 7.3 is less than specified minimum for a free source of 120.0 but variability index 168.63 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="4.79291844928"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.31267"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1111.857910"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="207.794"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="0.5142"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.418" name="3FGL J1355.0-1044" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.4180307847 degrees away from ROI center -->
# 	<!-- Source significane 11.6 is less than specified minimum for a free source of 120.0 but variability index 195.19 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="1.61558808866"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.38671"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="866.840149"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="208.752"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-10.7383"/>
# 	</spatialModel>
# </source>
#
# <!-- Sources between [16.0,24.0) degrees of ROI center -->
# <source ROI_Center_Distance="23.488" name="3FGL J1121.4-0554" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 23.4880514195 degrees away from ROI center -->
# 	<!-- Source significane 29.3 is less than specified minimum for a free source of 120.0 but variability index 812.47 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="5.88029191312"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.36649"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="756.827881"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="170.367"/>
# ...
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.34168"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="941.500000"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="224.688"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-21.3346"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="32.861" name="3FGL J1503.7-1540" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 32.8610746676 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="5.29824529518"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.76961"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="4462.026855"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="225.947"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-15.6758"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="35.907" name="3FGL J1504.4+1029" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 35.9070961523 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="norm" scale="1e-10" value="3.53900436734"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.07509"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.106493"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="345.173"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="226.105"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="10.4936"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="33.561" name="3FGL J1505.1+0326" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 33.5610225944 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-11" value="1.54160902793"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.60936"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="461.119385"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="226.278"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="3.4488"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="32.596" name="3FGL J1506.4-0340" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 32.596175494 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.65441797631"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.33324"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1571.513916"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="226.622"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.6684"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="35.486" name="3FGL J1506.6+0811" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 35.4860000741 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="5.44870206354"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.87401"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3324.551270"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="226.675"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="8.1846"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="39.940" name="3FGL J1507.4+1725" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 39.9395749621 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="1.02696739391"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.78348"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="5011.232422"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="226.869"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="17.4204"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="39.656" name="3FGL J1509.9-2951" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 39.6559507281 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="9.10309588126"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.78168"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="378.896118"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="227.484"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-29.864"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="33.591" name="3FGL J1510.9-0542" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 33.5910439587 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="3.84422138219"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.42557"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="882.636169"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="227.747"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.706"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="33.823" name="3FGL J1511.8-0513" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 33.823171338 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="7.24101971417"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.03408"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3617.744629"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="227.96"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.2191"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="34.933" name="3FGL J1512.2+0202" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 34.9334051172 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="2.38420893271"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.20014"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1014.934143"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="228.065"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="2.0334"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="37.037" name="3FGL J1512.2-2255" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 37.0370161772 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="6.07159044179"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.90673"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3318.802979"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="228.075"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-22.9312"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="34.087" name="3FGL J1512.8-0906" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 34.0874654635 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="norm" scale="1e-10" value="4.23298340824"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.30471"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.0748703"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="445.227"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="228.213"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-9.1032"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="34.241" name="3FGL J1513.1-1014" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 34.2410102867 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="2.19182679818"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.76539"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="737.600830"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="228.29"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-10.2412"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="38.451" name="3FGL J1513.4-2549" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 38.4505067223 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="norm" scale="1e-12" value="1.23074662441"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.03904"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.434396"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="1158.19"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="228.368"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-25.8271"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="38.729" name="3FGL J1517.6-2422" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 38.7289102278 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="5.50290455564"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.11215"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1029.804688"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="229.421"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-24.3756"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="36.144" name="3FGL J1520.8-0348" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 36.1444263789 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.21448613969"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.83412"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3223.897705"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="230.203"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.812"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="37.282" name="3FGL J1525.8-0834" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 37.2822822475 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="2.88983607043"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.64389"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="9857.482422"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="231.47"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-8.5792"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="39.332" name="3FGL J1532.7-1319" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 39.3321614191 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="3.32827233655"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.094"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1127.191772"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="233.188"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-13.3249"/>
# 	</spatialModel>
# </source>
#
# <!-- Diffuse Sources -->
# <source name="gll_iem_v06" type="DiffuseSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 		<parameter free="1" max="10" min="0" name="Prefactor" scale="1" value="1"/>
# 		<parameter free="0" max="1" min="-1" name="Index" scale="1.0" value="0"/>
# 		<parameter free="0" max="2e2" min="5e1" name="Scale" scale="1.0" value="1e2"/>
# 	</spectrum>
# 	<spatialModel file="/Users/Francis/ScienceTools-v10r0p5-fssc-patch-20150518-x86_64-apple-darwin14.4.0-without-root/x86_64-apple-darwin14.4.0/refdata/fermi/galdiffuse/gll_iem_v06.fits" type="MapCubeFunction">
# 		<parameter free="0" max="1e3" min="1e-3" name="Normalization" scale="1.0" value="1.0"/>
# 	</spatialModel>
# </source>
# <source name="iso_P8R2_SOURCE_V6_v06" type="DiffuseSource">
# 	<spectrum apply_edisp="false" file="/Users/Francis/ScienceTools-v10r0p5-fssc-patch-20150518-x86_64-apple-darwin14.4.0-without-root/x86_64-apple-darwin14.4.0/refdata/fermi/galdiffuse/iso_P8R2_SOURCE_V6_v06.txt" type="FileFunction">
# 		<parameter free="1" max="10" min="1e-2" name="Normalization" scale="1" value="1"/>
# 	</spectrum>
# 	<spatialModel type="ConstantValue">
# 		<parameter free="0" max="10.0" min="0.0" name="Value" scale="1.0" value="1.0"/>
# 	</spatialModel>
# </source>
# </source_library>

# %%
sources = source_library.findall('source')    # Puts data (of each node specified) into a list.
sourceParameters = source_library.findall('source/spectrum/parameter')

print ("First Source's attributes:")
print sources[0].attrib
# Out:
# First Source's attributes:
# {'type': 'PointSource', 'name': '3FGL J1228.4-0317', 'ROI_Center_Distance': '7.297'}

# %%
for s in sources:
    names = s.attrib.get('name')
    parameters = s.findall('spectrum/parameter') + s.findall('spatialModel/parameter')
    print names
    for p in parameters:
        print p.attrib.get('free')
# Out:
# 3FGL J1228.4-0317
# 0
# 0
# 0
# 0
# 0
# 3FGL J1233.7-0145
# 0
# 0
# 0
# 0
# 0
# 3FGL J1234.7-0437
# 0
# 0
# 0
# 0
# 0
# 3FGL J1239.1-1158
# 0
# 0
# 0
# 0
# 0
# 3FGL J1243.9-0217
# 0
# 0
# 0
# 0
# 0
# 3FGL J1249.5-0546
# 0
# 0
# 0
# 0
# 0
# 3FGL J1250.2-0233
# 0
# 0
# 0
# 0
# 0
# 3FGL J1251.0-0203
# 1
# 0
# 0
# 0
# 0
# 3FGL J1256.1-0547
# 1
# 1
# 1
# 0
# 0
# 0
# 3FGL J1256.3-1146
# 0
# 0
# 0
# 0
# 0
# 3FGL J1304.8-0338
# 1
# 0
# 0
# 0
# 0
# 3FGL J1310.2-1159
# 0
# 0
# 0
# 0
# 0
# 3FGL J1311.0+0036
# 0
# 0
# 0
# 0
# 0
# 3FGL J1312.7+0051
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 3FGL J1312.8-0424
# 1
# 0
# 0
# 0
# 0
# 3FGL J1315.7-0732
# 1
# 0
# 0
# 0
# 0
# 3FGL J1322.8-0938
# 1
# 0
# 0
# 0
# 0
# 3FGL J1155.3-1112
# 0
# 0
# 0
# 0
# 0
# 3FGL J1159.6-0723
# 0
# 0
# 0
# 0
# 0
# 3FGL J1200.4+0202
# 0
# 0
# 0
# 0
# 0
# 3FGL J1204.3-0708
# 0
# 0
# 0
# 0
# 0
# 3FGL J1216.6-0557
# 0
# 0
# 0
# 0
# 0
# 3FGL J1218.0-0029
# 1
# 0
# 0
# 0
# 0
# 3FGL J1218.4-0121
# 0
# 0
# 0
# 0
# 0
# 3FGL J1219.7-0314
# 0
# 0
# 0
# 0
# 0
# 3FGL J1221.5-0632
# 0
# 0
# 0
# 0
# 0
# 3FGL J1222.4+0414
# 1
# 0
# 0
# 0
# 0
# 0
# 3FGL J
# 0
# 0
# 0
# 0
# 0
# 0
# 3FGL J1513.1-1014
# 0
# 0
# 0
# 0
# 0
# 3FGL J1513.4-2549
# 0
# 0
# 0
# 0
# 0
# 0
# 3FGL J1517.6-2422
# 0
# 0
# 0
# 0
# 0
# 3FGL J1520.8-0348
# 0
# 0
# 0
# 0
# 0
# 3FGL J1525.8-0834
# 0
# 0
# 0
# 0
# 0
# 3FGL J1532.7-1319
# 0
# 0
# 0
# 0
# 0
# gll_iem_v06
# 1
# 0
# 0
# 0
# iso_P8R2_SOURCE_V6_v06
# 1
# 0

# %%
## For outputting Stars that have any parameter free="1"
for s in sources: 
    name = s.attrib.get('name')
    parameters = s.findall('spectrum/parameter') + s.findall('spatialModel/parameter')
    freeParameters = []
    for p in parameters:
        freeParameters.append(p.attrib.get('free'))
    if '1' in freeParameters:
        print name,freeParameters
# Out:
# 3FGL J1251.0-0203 ['1', '0', '0', '0', '0']
# 3FGL J1256.1-0547 ['1', '1', '1', '0', '0', '0']
# 3FGL J1304.8-0338 ['1', '0', '0', '0', '0']
# 3FGL J1312.8-0424 ['1', '0', '0', '0', '0']
# 3FGL J1315.7-0732 ['1', '0', '0', '0', '0']
# 3FGL J1322.8-0938 ['1', '0', '0', '0', '0']
# 3FGL J1218.0-0029 ['1', '0', '0', '0', '0']
# 3FGL J1222.4+0414 ['1', '0', '0', '0', '0', '0']
# 3FGL J1229.1+0202 ['1', '1', '1', '0', '0', '0']
# 3FGL J1239.5+0443 ['1', '0', '0', '0', '0', '0']
# 3FGL J1258.6-1800 ['1', '0', '0', '0', '0']
# 3FGL J1322.3+0839 ['1', '0', '0', '0', '0']
# 3FGL J1331.1-1328 ['1', '0', '0', '0', '0']
# 3FGL J1332.0-0508 ['1', '0', '0', '0', '0', '0']
# 3FGL J1332.6-1256 ['1', '0', '0', '0', '0']
# 3FGL J1337.6-1257 ['1', '0', '0', '0', '0', '0']
# 3FGL J1349.6-1133 ['1', '0', '0', '0', '0']
# 3FGL J1351.1+0030 ['1', '0', '0', '0', '0']
# 3FGL J1355.0-1044 ['1', '0', '0', '0', '0']
# 3FGL J1121.4-0554 ['1', '0', '0', '0', '0']
# 3FGL J1129.9-1446 ['1', '0', '0', '0', '0']
# 3FGL J1147.8-0725 ['1', '0', '0', '0', '0']
# 3FGL J1152.3-0841 ['1', '0', '0', '0', '0']
# 3FGL J1159.2-2141 ['1', '0', '0', '0', '0']
# 3FGL J1159.3-2226 ['1', '0', '0', '0', '0']
# 3FGL J1205.8-2636 ['1', '0', '0', '0', '0']
# 3FGL J1246.7-2547 ['1', '0', '0', '0', '0', '0']
# 3FGL J1258.7-2219 ['1', '0', '0', '0', '0']
# 3FGL J1300.2+1416 ['1', '0', '0', '0', '0']
# 3FGL J1341.9-2053 ['1', '0', '0', '0', '0']
# 3FGL J1344.2-1724 ['1', '0', '0', '0', '0', '0']
# 3FGL J1345.8+0704 ['1', '0', '0', '0', '0']
# 3FGL J1408.8-0751 ['1', '0', '0', '0', '0']
# 3FGL J1418.4-0233 ['1', '0', '0', '0', '0', '0']
# 3FGL J1419.5-0836 ['1', '0', '0', '0', '0']
# 3FGL J1059.2-1133 ['1', '0', '0', '0', '0']
# 3FGL J1115.0-0701 ['1', '0', '0', '0', '0']
# 3FGL J1118.2-0411 ['1', '0', '0', '0', '0']
# 3FGL J1127.0-1857 ['1', '0', '0', '0', '0', '0']
# 3FGL J1209.8+1810 ['1', '0', '0', '0', '0']
# 3FGL J1210.1-2742 ['1', '0', '0', '0', '0']
# 3FGL J1224.9+2122 ['1', '1', '1', '0', '0', '0']
# 3FGL J1316.0-3338 ['1', '0', '0', '0', '0']
# 3FGL J1321.0+2215 ['1', '0', '0', '0', '0']
# 3FGL J1326.8+2211 ['1', '0', '0', '0', '0', '0']
# 3FGL J1351.7-2913 ['1', '0', '0', '0', '0']
# 3FGL J1416.0+1325 ['1', '0', '0', '0', '0']
# 3FGL J1440.9+0610 ['1', '0', '0', '0', '0']
# gll_iem_v06 ['1', '0', '0', '0']
# iso_P8R2_SOURCE_V6_v06 ['1', '0']

# %%
print freeParameters
# Out:
# ['1', '0']

# %%
freeParameters[0] = '0'
print freeParameters
# Out:
# ['0', '0']

# %%
from lxml.builder import ElementMaker # lxml only !

E = ElementMaker(namespace="http://my.de/fault/namespace" , nsmap={'p' : "http://my.de/fault/namespace"})

DOC = E.doc
TITLE = E.title
SECTION = E.section
PAR = E.par
my_doc = DOC(TITLE("The dog and the hog"),
   SECTION(
     TITLE("The dog"),
     PAR("Once upon a time, ..."),
     PAR("And then ...")
   ),
   SECTION(
     TITLE("The hog"),
     PAR("Sooner or later ...")
   )
 )

print(etree.tostring(my_doc, pretty_print=True))
# Out:
# <p:doc xmlns:p="http://my.de/fault/namespace">
#   <p:title>The dog and the hog</p:title>
#   <p:section>
#     <p:title>The dog</p:title>
#     <p:par>Once upon a time, ...</p:par>
#     <p:par>And then ...</p:par>
#   </p:section>
#   <p:section>
#     <p:title>The hog</p:title>
#     <p:par>Sooner or later ...</p:par>
#   </p:section>
# </p:doc>

# %%
print xmlData
# Out:
# <source_library title="source library">
#
# <!-- Point Sources -->
#
# <!-- Sources between [0.0,8.0) degrees of ROI center -->
# <source ROI_Center_Distance="7.297" name="3FGL J1228.4-0317" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.29703262265 degrees away from ROI center -->
# 	<!-- Source signficance 5.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="2.12171277184"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.27196"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1458.882446"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="187.111"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.2954"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="6.864" name="3FGL J1233.7-0145" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 6.86421978889 degrees away from ROI center -->
# 	<!-- Source signficance 15.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="8.25105066736"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.22139"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1254.953003"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="188.434"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-1.7566"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="5.395" name="3FGL J1234.7-0437" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 5.39536678701 degrees away from ROI center -->
# 	<!-- Source signficance 4.9 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="3.90215966229"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.64911"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="8848.023438"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="188.697"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-4.6215"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.414" name="3FGL J1239.1-1158" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.41376789605 degrees away from ROI center -->
# 	<!-- Source signficance 6.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-11" value="2.22605267552"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="3.06671"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="270.158112"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="189.799"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.9776"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="4.634" name="3FGL J1243.9-0217" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 4.63377373269 degrees away from ROI center -->
# 	<!-- Source signficance 5.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.03579444284"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.18595"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1849.088135"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="190.977"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-2.2843"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="1.591" name="3FGL J1249.5-0546" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 1.59083496103 degrees away from ROI center -->
# 	<!-- Source signficance 5.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="2.2978496818"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.41291"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1453.287231"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="192.382"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.7794"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="3.548" name="3FGL J1250.2-0233" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 3.54770617793 degrees away from ROI center -->
# 	<!-- Source signficance 5.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-16" value="5.34960439679"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.09753"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="33148.875000"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="192.568"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-2.5638"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="3.954" name="3FGL J1251.0-0203" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 3.95445360053 degrees away from ROI center -->
# 	<!-- Source significane 6.9 is less than specified minimum for a free source of 120.0 but variability index 93.48 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="6.937092502"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.38573"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="958.773438"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="192.763"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-2.0566"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="0.067" name="3FGL J1256.1-0547" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 0.0673511866021 degrees away from ROI center -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-10" value="3.71426917001"/>
# 		<parameter free="1" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.23294"/>
# 		<parameter free="1" max="10.0" min="0.0" name="beta" scale="1.0" value="0.0789386"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="341.966"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="194.041"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.7912"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="5.962" name="3FGL J1256.3-1146" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 5.9617350176 degrees away from ROI center -->
# 	<!-- Source signficance 11.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="6.96275380559"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.90701"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3130.760010"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="194.087"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.7808"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="3.105" name="3FGL J1304.8-0338" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 3.10484964041 degrees away from ROI center -->
# 	<!-- Source significane 4.4 is less than specified minimum for a free source of 120.0 but variability index 73.54 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.57627993232"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.28052"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1462.262329"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="196.206"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.6478"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.111" name="3FGL J1310.2-1159" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.1105501606 degrees away from ROI center -->
# 	<!-- Source signficance 6.9 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="1.23810526379"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.79755"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="5606.663086"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="197.568"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.9852"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.465" name="3FGL J1311.0+0036" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.46462394463 degrees away from ROI center -->
# 	<!-- Source signficance 4.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="1.93439031747"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.54519"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="12643.100586"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="197.771"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="0.6138"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.896" name="3FGL J1312.7+0051" type="PointSource">
# 	<spectrum apply_edisp="false" type="PLSuperExpCutoff">
# 	<!-- Source is 7.8963708807 degrees away from ROI center -->
# 	<!-- Source significance 20.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="5.75055584748"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index1" scale="-1.0" value="1.52349"/>
# 		<parameter free="0" max="1e5" min="1e1" name="Cutoff" scale="1.0" value="2803.493408"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="837.744446"/>
# 		<parameter free="0" max="5" min="0" name="Index2" scale="1.0" value="1.000000"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="198.195"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="0.861"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="4.455" name="3FGL J1312.8-0424" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 4.45525925425 degrees away from ROI center -->
# 	<!-- Source significane 16.5 is less than specified minimum for a free source of 120.0 but variability index 388.24 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="4.81112155323"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.48721"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="616.724854"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="198.221"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-4.4027"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="5.227" name="3FGL J1315.7-0732" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 5.22727680817 degrees away from ROI center -->
# 	<!-- Source significane 12.9 is less than specified minimum for a free source of 120.0 but variability index 72.48 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.92119730498"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.01919"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2099.555420"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="198.947"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-7.5485"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.683" name="3FGL J1322.8-0938" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.68319932106 degrees away from ROI center -->
# 	<!-- Source significane 14.4 is less than specified minimum for a free source of 120.0 but variability index 178.64 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="8.2515383415"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.6294"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="480.361298"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="200.706"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-9.6449"/>
# 	</spatialModel>
# </source>
#
# <!-- Sources between [8.0,16.0) degrees of ROI center -->
# <source ROI_Center_Distance="15.917" name="3FGL J1155.3-1112" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.9170911067 degrees away from ROI center -->
# 	<!-- Source signficance 5.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="4.40638482326"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.53449"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="7846.404785"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="178.827"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.2029"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.068" name="3FGL J1159.6-0723" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.0676843761 degrees away from ROI center -->
# 	<!-- Source signficance 8.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.21623007889"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.1039"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2149.063477"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="179.906"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-7.3924"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.926" name="3FGL J1200.4+0202" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.9264684902 degrees away from ROI center -->
# 	<!-- Source signficance 8.8 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.21578325207"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.03552"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2072.597900"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="180.111"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="2.0418"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.871" name="3FGL J1204.3-0708" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.8705990938 degrees away from ROI center -->
# 	<!-- Source signficance 15.8 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.26072682025"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.8612"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2905.877197"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="181.094"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-7.1411"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.768" name="3FGL J1216.6-0557" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 9.76826564273 degrees away from ROI center -->
# 	<!-- Source signficance 4.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="7.0740846991"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.483"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="847.284363"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="184.161"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.9646"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.845" name="3FGL J1218.0-0029" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 10.8453070836 degrees away from ROI center -->
# 	<!-- Source significane 8.7 is less than specified minimum for a free source of 120.0 but variability index 83.88 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="7.23918266912"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.38836"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1099.319824"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="184.513"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-0.4972"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.361" name="3FGL J1218.4-0121" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 10.3612160665 degrees away from ROI center -->
# 	<!-- Source signficance 13.8 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="5.04116767861"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.19519"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1561.669312"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="184.606"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-1.3627"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.382" name="3FGL J1219.7-0314" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 9.38160159135 degrees away from ROI center -->
# 	<!-- Source signficance 8.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.03773807852"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.00122"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2359.194092"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="184.932"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.2353"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="8.583" name="3FGL J1221.5-0632" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 8.58297679387 degrees away from ROI center -->
# 	<!-- Source signficance 11.5 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="6.0494128153"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.24979"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1255.948364"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="185.378"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-6.55"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="13.074" name="3FGL J1222.4+0414" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 13.0741398375 degrees away from ROI center -->
# 	<!-- Source significance 30.0 is less than specified minimum for a free source of 120.0 but variability index 188.40 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-10" value="1.11763286126"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.50852"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.214161"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="263.937"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="185.611"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="4.234"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.431" name="3FGL J1226.8+0638" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.4310937065 degrees away from ROI center -->
# 	<!-- Source signficance 5.5 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="3.46949502107"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.56446"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="8902.508789"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="186.7"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="6.649"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.478" name="3FGL J1226.9-1329" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 10.4784830665 degrees away from ROI center -->
# 	<!-- Source signficance 13.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.68987328471"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.98275"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2482.793701"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="186.742"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-13.4988"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.318" name="3FGL J1229.1+0202" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 10.3182857241 degrees away from ROI center -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-10" value="7.64849072965"/>
# 		<parameter free="1" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.51628"/>
# 		<parameter free="1" max="10.0" min="0.0" name="beta" scale="1.0" value="0.107886"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="245.941"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="187.287"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="2.041"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.351" name="3FGL J1231.2-1411" type="PointSource">
# 	<spectrum apply_edisp="false" type="PLSuperExpCutoff">
# 	<!-- Source is 10.3508469452 degrees away from ROI center -->
# 	<!-- Source significance 105.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-11" value="3.08963236939"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index1" scale="-1.0" value="1.1804"/>
# 		<parameter free="0" max="1e5" min="1e1" name="Cutoff" scale="1.0" value="2574.697754"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="917.884216"/>
# 		<parameter free="0" max="5" min="0" name="Index2" scale="1.0" value="1.000000"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="187.801"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-14.1981"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.799" name="3FGL J1238.2-1958" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.7988431438 degrees away from ROI center -->
# 	<!-- Source signficance 8.5 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="6.58906685724"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.34868"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1030.790894"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="189.565"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-19.9831"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="13.900" name="3FGL J1239.4+0727" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 13.9000544694 degrees away from ROI center -->
# 	<!-- Source signficance 8.0 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="6.82570644971"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.39759"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1011.890381"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="189.873"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="7.4625"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.301" name="3FGL J1239.5+0443" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 11.3010308437 degrees away from ROI center -->
# 	<!-- Source significance 65.0 is less than specified minimum for a free source of 120.0 but variability index 1257.65 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-11" value="6.12414355339"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.20432"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.112085"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="424.897"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="189.895"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="4.7192"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.777" name="3FGL J1241.6-1456" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 9.7774006442 degrees away from ROI center -->
# 	<!-- Source signficance 6.2 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="3.87271425594"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.95942"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3020.241455"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="190.406"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-14.9452"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.962" name="3FGL J1241.9+0639" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.962172155 degrees away from ROI center -->
# 	<!-- Source signficance 5.2 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="9.04040382187"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.78168"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="5711.555176"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="190.475"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="6.6613"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="8.229" name="3FGL J1250.5+0217" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 8.22873148558 degrees away from ROI center -->
# 	<!-- Source signficance 6.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="3.1433341173"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.32794"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1259.425415"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="192.626"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="2.2969"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.300" name="3FGL J1253.7+0327" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 9.30015252631 degrees away from ROI center -->
# 	<!-- Source signficance 12.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="6.69547222027"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.84179"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3417.689453"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="193.435"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="3.4642"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.201" name="3FGL J1258.6-1800" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.2014547221 degrees away from ROI center -->
# 	<!-- Source significane 22.4 is less than specified minimum for a free source of 120.0 but variability index 247.30 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="9.17906636116"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.44648"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="557.331421"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="194.65"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-18.0039"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.431" name="3FGL J1301.6+0832" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.4312246135 degrees away from ROI center -->
# 	<!-- Source signficance 13.6 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="2.14075393697"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.37894"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="765.506470"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="195.418"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="8.5398"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.494" name="3FGL J1304.9-2109" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.4938483749 degrees away from ROI center -->
# 	<!-- Source signficance 4.9 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="5.8130482036"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.14788"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2515.447998"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="196.246"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-21.1575"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.153" name="3FGL J1309.0+0347" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 10.1531010759 degrees away from ROI center -->
# 	<!-- Source signficance 4.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="6.743807986"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.08547"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1972.809570"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="197.258"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="3.7909"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="8.772" name="3FGL J1318.7-1232" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 8.77218567895 degrees away from ROI center -->
# 	<!-- Source signficance 8.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="7.51060617778"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.34752"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="992.460327"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="199.694"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-12.5408"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.904" name="3FGL J1322.3+0839" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.9036567867 degrees away from ROI center -->
# 	<!-- Source significane 7.8 is less than specified minimum for a free source of 120.0 but variability index 73.85 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="3.70699104009"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.25257"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1232.444214"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="200.582"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="8.6574"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.375" name="3FGL J1322.6-1619" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.3751905452 degrees away from ROI center -->
# 	<!-- Source signficance 5.3 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="3.88026091293"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.35643"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1108.856079"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="200.666"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-16.3189"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.409" name="3FGL J1322.9+0435" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.4089883853 degrees away from ROI center -->
# 	<!-- Source signficance 6.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="1.13660030823"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.73958"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="5297.357422"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="200.733"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="4.5966"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="8.280" name="3FGL J1329.1-0536" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 8.28049245461 degrees away from ROI center -->
# 	<!-- Source signficance 5.6 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.8921494959"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.35159"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1727.645752"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="202.299"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.6081"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.574" name="3FGL J1331.1-1328" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 11.5742648687 degrees away from ROI center -->
# 	<!-- Source significane 5.5 is less than specified minimum for a free source of 120.0 but variability index 81.58 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="2.54386762306"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.3738"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1526.140991"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="202.787"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-13.4818"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.018" name="3FGL J1332.0-0508" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 9.01841422236 degrees away from ROI center -->
# 	<!-- Source significance 49.7 is less than specified minimum for a free source of 120.0 but variability index 1874.97 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-11" value="4.10766663739"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.45441"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.17614"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="543.838"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="203.015"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.1476"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.513" name="3FGL J1332.6-1256" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 11.5130398587 degrees away from ROI center -->
# 	<!-- Source significane 19.3 is less than specified minimum for a free source of 120.0 but variability index 296.67 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="2.37151227475"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.41706"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1056.578247"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="203.158"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-12.9387"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.521" name="3FGL J1337.6-1257" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 12.5208433017 degrees away from ROI center -->
# 	<!-- Source significance 19.1 is less than specified minimum for a free source of 120.0 but variability index 100.09 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-12" value="6.05034642179"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.36626"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.205617"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="715.704"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="204.415"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-12.9571"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.766" name="3FGL J1339.8-0133" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 11.7660737304 degrees away from ROI center -->
# 	<!-- Source signficance 5.0 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="1.0200105734"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.46877"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="723.633972"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="204.971"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-1.5556"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.270" name="3FGL J1340.6-0408" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 11.2696173964 degrees away from ROI center -->
# 	<!-- Source signficance 6.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="7.200698913"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.98138"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2449.177246"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="205.166"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-4.1371"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.454" name="3FGL J1349.6-1133" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.454329785 degrees away from ROI center -->
# 	<!-- Source significane 18.4 is less than specified minimum for a free source of 120.0 but variability index 642.10 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="3
/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-13.3249"/>
# 	</spatialModel>
# </source>
#
# <!-- Diffuse Sources -->
# <source name="gll_iem_v06" type="DiffuseSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 		<parameter free="1" max="10" min="0" name="Prefactor" scale="1" value="1"/>
# 		<parameter free="0" max="1" min="-1" name="Index" scale="1.0" value="0"/>
# 		<parameter free="0" max="2e2" min="5e1" name="Scale" scale="1.0" value="1e2"/>
# 	</spectrum>
# 	<spatialModel file="/Users/Francis/ScienceTools-v10r0p5-fssc-patch-20150518-x86_64-apple-darwin14.4.0-without-root/x86_64-apple-darwin14.4.0/refdata/fermi/galdiffuse/gll_iem_v06.fits" type="MapCubeFunction">
# 		<parameter free="0" max="1e3" min="1e-3" name="Normalization" scale="1.0" value="1.0"/>
# 	</spatialModel>
# </source>
# <source name="iso_P8R2_SOURCE_V6_v06" type="DiffuseSource">
# 	<spectrum apply_edisp="false" file="/Users/Francis/ScienceTools-v10r0p5-fssc-patch-20150518-x86_64-apple-darwin14.4.0-without-root/x86_64-apple-darwin14.4.0/refdata/fermi/galdiffuse/iso_P8R2_SOURCE_V6_v06.txt" type="FileFunction">
# 		<parameter free="1" max="10" min="1e-2" name="Normalization" scale="1" value="1"/>
# 	</spectrum>
# 	<spatialModel type="ConstantValue">
# 		<parameter free="0" max="10.0" min="0.0" name="Value" scale="1.0" value="1.0"/>
# 	</spatialModel>
# </source>
# </source_library>

# %%
xmlData.find("free=")
# Out:
# 418

# %%
print sources[0].attrib
# Out:
# {'type': 'PointSource', 'name': '3FGL J1228.4-0317', 'ROI_Center_Distance': '7.297'}

# %%
## Here I changed the attribute, 'name' of the first source to 'UPDATED NAME'
sources[0].set('name','UPDATED NAME')
print sources[0].attrib
# Out:
# {'type': 'PointSource', 'name': 'UPDATED NAME', 'ROI_Center_Distance': '7.297'}

# %%
## UPDATED xml file (new name for first source)
print etree.tostring(source_library, pretty_print=True)
# Out:
# <source_library title="source library">
#
# <!-- Point Sources -->
#
# <!-- Sources between [0.0,8.0) degrees of ROI center -->
# <source ROI_Center_Distance="7.297" name="UPDATED NAME" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.29703262265 degrees away from ROI center -->
# 	<!-- Source signficance 5.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="2.12171277184"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.27196"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1458.882446"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="187.111"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.2954"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="6.864" name="3FGL J1233.7-0145" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 6.86421978889 degrees away from ROI center -->
# 	<!-- Source signficance 15.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="8.25105066736"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.22139"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1254.953003"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="188.434"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-1.7566"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="5.395" name="3FGL J1234.7-0437" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 5.39536678701 degrees away from ROI center -->
# 	<!-- Source signficance 4.9 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="3.90215966229"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.64911"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="8848.023438"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="188.697"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-4.6215"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.414" name="3FGL J1239.1-1158" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.41376789605 degrees away from ROI center -->
# 	<!-- Source signficance 6.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-11" value="2.22605267552"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="3.06671"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="270.158112"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="189.799"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.9776"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="4.634" name="3FGL J1243.9-0217" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 4.63377373269 degrees away from ROI center -->
# 	<!-- Source signficance 5.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.03579444284"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.18595"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1849.088135"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="190.977"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-2.2843"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="1.591" name="3FGL J1249.5-0546" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 1.59083496103 degrees away from ROI center -->
# 	<!-- Source signficance 5.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="2.2978496818"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.41291"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1453.287231"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="192.382"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.7794"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="3.548" name="3FGL J1250.2-0233" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 3.54770617793 degrees away from ROI center -->
# 	<!-- Source signficance 5.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-16" value="5.34960439679"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.09753"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="33148.875000"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="192.568"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-2.5638"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="3.954" name="3FGL J1251.0-0203" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 3.95445360053 degrees away from ROI center -->
# 	<!-- Source significane 6.9 is less than specified minimum for a free source of 120.0 but variability index 93.48 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="6.937092502"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.38573"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="958.773438"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="192.763"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-2.0566"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="0.067" name="3FGL J1256.1-0547" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 0.0673511866021 degrees away from ROI center -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-10" value="3.71426917001"/>
# 		<parameter free="1" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.23294"/>
# 		<parameter free="1" max="10.0" min="0.0" name="beta" scale="1.0" value="0.0789386"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="341.966"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="194.041"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.7912"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="5.962" name="3FGL J1256.3-1146" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 5.9617350176 degrees away from ROI center -->
# 	<!-- Source signficance 11.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="6.96275380559"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.90701"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3130.760010"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="194.087"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.7808"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="3.105" name="3FGL J1304.8-0338" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 3.10484964041 degrees away from ROI center -->
# 	<!-- Source significane 4.4 is less than specified minimum for a free source of 120.0 but variability index 73.54 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.57627993232"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.28052"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1462.262329"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="196.206"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.6478"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.111" name="3FGL J1310.2-1159" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.1105501606 degrees away from ROI center -->
# 	<!-- Source signficance 6.9 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="1.23810526379"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.79755"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="5606.663086"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="197.568"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.9852"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.465" name="3FGL J1311.0+0036" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.46462394463 degrees away from ROI center -->
# 	<!-- Source signficance 4.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="1.93439031747"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.54519"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="12643.100586"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="197.771"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="0.6138"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.896" name="3FGL J1312.7+0051" type="PointSource">
# 	<spectrum apply_edisp="false" type="PLSuperExpCutoff">
# 	<!-- Source is 7.8963708807 degrees away from ROI center -->
# 	<!-- Source significance 20.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="5.75055584748"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index1" scale="-1.0" value="1.52349"/>
# 		<parameter free="0" max="1e5" min="1e1" name="Cutoff" scale="1.0" value="2803.493408"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="837.744446"/>
# 		<parameter free="0" max="5" min="0" name="Index2" scale="1.0" value="1.000000"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="198.195"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="0.861"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="4.455" name="3FGL J1312.8-0424" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 4.45525925425 degrees away from ROI center -->
# 	<!-- Source significane 16.5 is less than specified minimum for a free source of 120.0 but variability index 388.24 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="4.81112155323"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.48721"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="616.724854"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="198.221"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-4.4027"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="5.227" name="3FGL J1315.7-0732" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 5.22727680817 degrees away from ROI center -->
# 	<!-- Source significane 12.9 is less than specified minimum for a free source of 120.0 but variability index 72.48 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.92119730498"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.01919"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2099.555420"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="198.947"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-7.5485"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="7.683" name="3FGL J1322.8-0938" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 7.68319932106 degrees away from ROI center -->
# 	<!-- Source significane 14.4 is less than specified minimum for a free source of 120.0 but variability index 178.64 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="8.2515383415"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.6294"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="480.361298"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="200.706"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-9.6449"/>
# 	</spatialModel>
# </source>
#
# <!-- Sources between [8.0,16.0) degrees of ROI center -->
# <source ROI_Center_Distance="15.917" name="3FGL J1155.3-1112" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.9170911067 degrees away from ROI center -->
# 	<!-- Source signficance 5.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="4.40638482326"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.53449"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="7846.404785"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="178.827"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.2029"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.068" name="3FGL J1159.6-0723" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.0676843761 degrees away from ROI center -->
# 	<!-- Source signficance 8.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.21623007889"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.1039"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2149.063477"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="179.906"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-7.3924"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.926" name="3FGL J1200.4+0202" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.9264684902 degrees away from ROI center -->
# 	<!-- Source signficance 8.8 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.21578325207"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.03552"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2072.597900"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="180.111"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="2.0418"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.871" name="3FGL J1204.3-0708" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.8705990938 degrees away from ROI center -->
# 	<!-- Source signficance 15.8 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.26072682025"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.8612"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2905.877197"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="181.094"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-7.1411"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.768" name="3FGL J1216.6-0557" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 9.76826564273 degrees away from ROI center -->
# 	<!-- Source signficance 4.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="7.0740846991"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.483"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="847.284363"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="184.161"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.9646"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.845" name="3FGL J1218.0-0029" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 10.8453070836 degrees away from ROI center -->
# 	<!-- Source significane 8.7 is less than specified minimum for a free source of 120.0 but variability index 83.88 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="7.23918266912"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.38836"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1099.319824"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="184.513"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-0.4972"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.361" name="3FGL J1218.4-0121" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 10.3612160665 degrees away from ROI center -->
# 	<!-- Source signficance 13.8 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="5.04116767861"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.19519"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1561.669312"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="184.606"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-1.3627"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.382" name="3FGL J1219.7-0314" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 9.38160159135 degrees away from ROI center -->
# 	<!-- Source signficance 8.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.03773807852"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.00122"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2359.194092"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="184.932"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.2353"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="8.583" name="3FGL J1221.5-0632" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 8.58297679387 degrees away from ROI center -->
# 	<!-- Source signficance 11.5 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="6.0494128153"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.24979"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1255.948364"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="185.378"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-6.55"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="13.074" name="3FGL J1222.4+0414" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 13.0741398375 degrees away from ROI center -->
# 	<!-- Source significance 30.0 is less than specified minimum for a free source of 120.0 but variability index 188.40 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-10" value="1.11763286126"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.50852"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.214161"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="263.937"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="185.611"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="4.234"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.431" name="3FGL J1226.8+0638" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.4310937065 degrees away from ROI center -->
# 	<!-- Source signficance 5.5 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="3.46949502107"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.56446"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="8902.508789"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="186.7"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="6.649"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.478" name="3FGL J1226.9-1329" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 10.4784830665 degrees away from ROI center -->
# 	<!-- Source signficance 13.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.68987328471"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.98275"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2482.793701"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="186.742"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-13.4988"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.318" name="3FGL J1229.1+0202" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 10.3182857241 degrees away from ROI center -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-10" value="7.64849072965"/>
# 		<parameter free="1" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.51628"/>
# 		<parameter free="1" max="10.0" min="0.0" name="beta" scale="1.0" value="0.107886"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="245.941"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="187.287"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="2.041"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.351" name="3FGL J1231.2-1411" type="PointSource">
# 	<spectrum apply_edisp="false" type="PLSuperExpCutoff">
# 	<!-- Source is 10.3508469452 degrees away from ROI center -->
# 	<!-- Source significance 105.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-11" value="3.08963236939"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index1" scale="-1.0" value="1.1804"/>
# 		<parameter free="0" max="1e5" min="1e1" name="Cutoff" scale="1.0" value="2574.697754"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="917.884216"/>
# 		<parameter free="0" max="5" min="0" name="Index2" scale="1.0" value="1.000000"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="187.801"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-14.1981"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.799" name="3FGL J1238.2-1958" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.7988431438 degrees away from ROI center -->
# 	<!-- Source signficance 8.5 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="6.58906685724"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.34868"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1030.790894"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="189.565"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-19.9831"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="13.900" name="3FGL J1239.4+0727" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 13.9000544694 degrees away from ROI center -->
# 	<!-- Source signficance 8.0 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="6.82570644971"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.39759"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1011.890381"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="189.873"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="7.4625"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.301" name="3FGL J1239.5+0443" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 11.3010308437 degrees away from ROI center -->
# 	<!-- Source significance 65.0 is less than specified minimum for a free source of 120.0 but variability index 1257.65 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-11" value="6.12414355339"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.20432"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.112085"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="424.897"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="189.895"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="4.7192"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.777" name="3FGL J1241.6-1456" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 9.7774006442 degrees away from ROI center -->
# 	<!-- Source signficance 6.2 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="3.87271425594"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.95942"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3020.241455"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="190.406"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-14.9452"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.962" name="3FGL J1241.9+0639" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.962172155 degrees away from ROI center -->
# 	<!-- Source signficance 5.2 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="9.04040382187"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.78168"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="5711.555176"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="190.475"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="6.6613"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="8.229" name="3FGL J1250.5+0217" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 8.22873148558 degrees away from ROI center -->
# 	<!-- Source signficance 6.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="3.1433341173"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.32794"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1259.425415"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="192.626"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="2.2969"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.300" name="3FGL J1253.7+0327" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 9.30015252631 degrees away from ROI center -->
# 	<!-- Source signficance 12.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="6.69547222027"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.84179"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3417.689453"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="193.435"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="3.4642"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.201" name="3FGL J1258.6-1800" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.2014547221 degrees away from ROI center -->
# 	<!-- Source significane 22.4 is less than specified minimum for a free source of 120.0 but variability index 247.30 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="9.17906636116"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.44648"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="557.331421"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="194.65"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-18.0039"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.431" name="3FGL J1301.6+0832" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.4312246135 degrees away from ROI center -->
# 	<!-- Source signficance 13.6 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="2.14075393697"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.37894"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="765.506470"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="195.418"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="8.5398"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.494" name="3FGL J1304.9-2109" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.4938483749 degrees away from ROI center -->
# 	<!-- Source signficance 4.9 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="5.8130482036"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.14788"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2515.447998"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="196.246"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-21.1575"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="10.153" name="3FGL J1309.0+0347" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 10.1531010759 degrees away from ROI center -->
# 	<!-- Source signficance 4.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="6.743807986"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.08547"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1972.809570"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="197.258"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="3.7909"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="8.772" name="3FGL J1318.7-1232" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 8.77218567895 degrees away from ROI center -->
# 	<!-- Source signficance 8.4 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="7.51060617778"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.34752"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="992.460327"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="199.694"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-12.5408"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.904" name="3FGL J1322.3+0839" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.9036567867 degrees away from ROI center -->
# 	<!-- Source significane 7.8 is less than specified minimum for a free source of 120.0 but variability index 73.85 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="3.70699104009"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.25257"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1232.444214"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="200.582"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="8.6574"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.375" name="3FGL J1322.6-1619" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.3751905452 degrees away from ROI center -->
# 	<!-- Source signficance 5.3 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="3.88026091293"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.35643"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1108.856079"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="200.666"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-16.3189"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.409" name="3FGL J1322.9+0435" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 12.4089883853 degrees away from ROI center -->
# 	<!-- Source signficance 6.1 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="1.13660030823"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.73958"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="5297.357422"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="200.733"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="4.5966"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="8.280" name="3FGL J1329.1-0536" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 8.28049245461 degrees away from ROI center -->
# 	<!-- Source signficance 5.6 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.8921494959"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.35159"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1727.645752"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="202.299"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.6081"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.574" name="3FGL J1331.1-1328" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 11.5742648687 degrees away from ROI center -->
# 	<!-- Source significane 5.5 is less than specified minimum for a free source of 120.0 but variability index 81.58 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="2.54386762306"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.3738"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1526.140991"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="202.787"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-13.4818"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="9.018" name="3FGL J1332.0-0508" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 9.01841422236 degrees away from ROI center -->
# 	<!-- Source significance 49.7 is less than specified minimum for a free source of 120.0 but variability index 1874.97 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-11" value="4.10766663739"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.45441"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.17614"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="543.838"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="203.015"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.1476"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.513" name="3FGL J1332.6-1256" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 11.5130398587 degrees away from ROI center -->
# 	<!-- Source significane 19.3 is less than specified minimum for a free source of 120.0 but variability index 296.67 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="2.37151227475"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.41706"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1056.578247"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="203.158"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-12.9387"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="12.521" name="3FGL J1337.6-1257" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 12.5208433017 degrees away from ROI center -->
# 	<!-- Source significance 19.1 is less than specified minimum for a free source of 120.0 but variability index 100.09 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="norm" scale="1e-12" value="6.05034642179"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.36626"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.205617"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="715.704"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="204.415"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-12.9571"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.766" name="3FGL J1339.8-0133" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 11.7660737304 degrees away from ROI center -->
# 	<!-- Source signficance 5.0 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="1.0200105734"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.46877"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="723.633972"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="204.971"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-1.5556"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="11.270" name="3FGL J1340.6-0408" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 11.2696173964 degrees away from ROI center -->
# 	<!-- Source signficance 6.7 is less than specified minimum for a free source of 120.0 -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="7.200698913"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.98138"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="2449.177246"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="205.166"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-4.1371"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="14.454" name="3FGL J1349.6-1133" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 14.454329785 degrees away from ROI center -->
# 	<!-- Source significane 18.4 is less than specified minimum for a free source of 120.0 but variability index 642.10 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="3.49776652954"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.39194"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="770.664734"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="207.407"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-11.5596"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.177" name="3FGL J1351.1+0030" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.1773061922 degrees away from ROI center -->
# 	<!-- Source significane 7.3 is less than specified minimum for a free source of 120.0 but variability index 168.63 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="4.79291844928"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.31267"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1111.857910"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="207.794"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="0.5142"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="15.418" name="3FGL J1355.0-1044" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 15.4180307847 degrees away from ROI center -->
# 	<!-- Source significane 11.6 is less than specified minimum for a free source of 120.0 but variability index 195.19 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="1.61558808866"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.38671"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="866.840149"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="208.752"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-10.7383"/>
# 	</spatialModel>
# </source>
#
# <!-- Sources between [16.0,24.0) degrees of ROI center -->
# <source ROI_Center_Distance="23.488" name="3FGL J1121.4-0554" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 23.4880514195 degrees away from ROI center -->
# 	<!-- Source significane 29.3 is less than specified minimum for a free source of 120.0 but variability index 812.47 is greater than 72.44 and varFree is set to True -->
# 		<parameter free="1" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="5.88029191312"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.36649"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="756.827881"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="170.367"/>
# ...
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.34168"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="941.500000"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="224.688"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-21.3346"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="32.861" name="3FGL J1503.7-1540" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 32.8610746676 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="5.29824529518"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.76961"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="4462.026855"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="225.947"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-15.6758"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="35.907" name="3FGL J1504.4+1029" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 35.9070961523 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="norm" scale="1e-10" value="3.53900436734"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.07509"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.106493"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="345.173"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="226.105"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="10.4936"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="33.561" name="3FGL J1505.1+0326" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 33.5610225944 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-11" value="1.54160902793"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.60936"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="461.119385"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="226.278"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="3.4488"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="32.596" name="3FGL J1506.4-0340" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 32.596175494 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.65441797631"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.33324"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1571.513916"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="226.622"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.6684"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="35.486" name="3FGL J1506.6+0811" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 35.4860000741 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="5.44870206354"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.87401"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3324.551270"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="226.675"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="8.1846"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="39.940" name="3FGL J1507.4+1725" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 39.9395749621 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="1.02696739391"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.78348"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="5011.232422"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="226.869"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="17.4204"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="39.656" name="3FGL J1509.9-2951" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 39.6559507281 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="9.10309588126"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.78168"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="378.896118"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="227.484"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-29.864"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="33.591" name="3FGL J1510.9-0542" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 33.5910439587 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="3.84422138219"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.42557"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="882.636169"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="227.747"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.706"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="33.823" name="3FGL J1511.8-0513" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 33.823171338 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="7.24101971417"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.03408"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3617.744629"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="227.96"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-5.2191"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="34.933" name="3FGL J1512.2+0202" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 34.9334051172 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="2.38420893271"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.20014"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1014.934143"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="228.065"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="2.0334"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="37.037" name="3FGL J1512.2-2255" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 37.0370161772 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-14" value="6.07159044179"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.90673"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3318.802979"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="228.075"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-22.9312"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="34.087" name="3FGL J1512.8-0906" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 34.0874654635 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="norm" scale="1e-10" value="4.23298340824"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.30471"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.0748703"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="445.227"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="228.213"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-9.1032"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="34.241" name="3FGL J1513.1-1014" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 34.2410102867 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="2.19182679818"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.76539"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="737.600830"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="228.29"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-10.2412"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="38.451" name="3FGL J1513.4-2549" type="PointSource">
# 	<spectrum apply_edisp="false" type="LogParabola">
# 	<!-- Source is 38.4505067223 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="norm" scale="1e-12" value="1.23074662441"/>
# 		<parameter free="0" max="5.0" min="0.0" name="alpha" scale="1.0" value="2.03904"/>
# 		<parameter free="0" max="10.0" min="0.0" name="beta" scale="1.0" value="0.434396"/>
# 		<parameter free="0" max="5e5" min="30" name="Eb" scale="1.0" value="1158.19"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="228.368"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-25.8271"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="38.729" name="3FGL J1517.6-2422" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 38.7289102278 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="5.50290455564"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.11215"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1029.804688"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="229.421"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-24.3756"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="36.144" name="3FGL J1520.8-0348" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 36.1444263789 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-13" value="1.21448613969"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.83412"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="3223.897705"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="230.203"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-3.812"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="37.282" name="3FGL J1525.8-0834" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 37.2822822475 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-15" value="2.88983607043"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="1.64389"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="9857.482422"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="231.47"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-8.5792"/>
# 	</spatialModel>
# </source>
# <source ROI_Center_Distance="39.332" name="3FGL J1532.7-1319" type="PointSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 	<!-- Source is 39.3321614191 degrees away from ROI center -->
# 	<!-- Source is outside ROI, all parameters should remain fixed -->
# 		<parameter free="0" max="1e4" min="1e-4" name="Prefactor" scale="1e-12" value="3.32827233655"/>
# 		<parameter free="0" max="10.0" min="0.0" name="Index" scale="-1.0" value="2.094"/>
# 		<parameter free="0" max="5e5" min="30" name="Scale" scale="1.0" value="1127.191772"/>
# 	</spectrum>
# 	<spatialModel type="SkyDirFunction">
# 		<parameter free="0" max="360.0" min="-360.0" name="RA" scale="1.0" value="233.188"/>
# 		<parameter free="0" max="90" min="-90" name="DEC" scale="1.0" value="-13.3249"/>
# 	</spatialModel>
# </source>
#
# <!-- Diffuse Sources -->
# <source name="gll_iem_v06" type="DiffuseSource">
# 	<spectrum apply_edisp="false" type="PowerLaw">
# 		<parameter free="1" max="10" min="0" name="Prefactor" scale="1" value="1"/>
# 		<parameter free="0" max="1" min="-1" name="Index" scale="1.0" value="0"/>
# 		<parameter free="0" max="2e2" min="5e1" name="Scale" scale="1.0" value="1e2"/>
# 	</spectrum>
# 	<spatialModel file="/Users/Francis/ScienceTools-v10r0p5-fssc-patch-20150518-x86_64-apple-darwin14.4.0-without-root/x86_64-apple-darwin14.4.0/refdata/fermi/galdiffuse/gll_iem_v06.fits" type="MapCubeFunction">
# 		<parameter free="0" max="1e3" min="1e-3" name="Normalization" scale="1.0" value="1.0"/>
# 	</spatialModel>
# </source>
# <source name="iso_P8R2_SOURCE_V6_v06" type="DiffuseSource">
# 	<spectrum apply_edisp="false" file="/Users/Francis/ScienceTools-v10r0p5-fssc-patch-20150518-x86_64-apple-darwin14.4.0-without-root/x86_64-apple-darwin14.4.0/refdata/fermi/galdiffuse/iso_P8R2_SOURCE_V6_v06.txt" type="FileFunction">
# 		<parameter free="1" max="10" min="1e-2" name="Normalization" scale="1" value="1"/>
# 	</spectrum>
# 	<spatialModel type="ConstantValue">
# 		<parameter free="0" max="10.0" min="0.0" name="Value" scale="1.0" value="1.0"/>
# 	</spatialModel>
# </source>
# </source_library>
